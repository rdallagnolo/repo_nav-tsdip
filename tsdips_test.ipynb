# %%
import pandas as pd
from datetime import datetime
import plotly.express as px
import plotly.graph_objects as go
import plotly.io as pio
import numpy as np

# %%
pio.templates
# Out:
# Templates configuration
# -----------------------
#     Default template: 'plotly'
#     Available templates:
#         ['ggplot2', 'seaborn', 'simple_white', 'plotly',
#          'plotly_white', 'plotly_dark', 'presentation', 'xgridoff',
#          'ygridoff', 'gridon', 'none']

# %%
target = "TSDip-1.txt"

# %%
df = pd.read_csv(f"/home/rod/Documents/DataScience/my_projects/nav/tsdip/data/{target}",sep="\t")

# %% [markdown]
# ## Cleaning up and refactoring column names

# %%
df.drop(['SS','FileName','Ser','Meas ','Sal. ','Cond. ','Temp ',' %O2 ','mg/l'],axis=1,inplace=True) # droping unused columns
df.columns=['SoS','Depth','year','month','day','hour','minute','second']                             # renaming columns
df = df[df['Depth']>2.0]                                                                             # keep only  depths above 2.0 meters
df['date']=pd.to_datetime(df[['year', 'month', 'day', 'hour','minute','second']])                    # parsing datetime columnes to single 'date' columns
#df.drop(['year', 'month', 'day', 'hour','minute','second'],axis=1,inplace=True)                      # droping date and time not to be used
#df["Date"] = df["date"].dt.date                                                                      # splitting date
#df["Time"] = df["date"].dt.time                                                                      # spliting time
#df.drop("date",axis=1,inplace=True)                                                                  # droping single 'datetime' column
#df.reset_index(inplace=True)                                                                         # reset index
#df.reset_index(inplace=True)                                                                         # reset index again to get correct index column

# %%
df['time_shift'] = df['date'].shift()

# %%
df['time_diff']=(df['date']-df['time_shift'])/ pd.Timedelta(seconds=1)

# %%
df
# Out:
#           SoS  Depth  year  month  day  hour  minute  second  \
# 19    1540.96   2.93  2022     11    7     4      34      16
# 20    1540.92   3.44  2022     11    7     4      34      18
# 21    1540.92   3.95  2022     11    7     4      34      20
# 22    1540.90   4.48  2022     11    7     4      34      22
# 23    1540.91   5.29  2022     11    7     4      34      24
# ...       ...    ...   ...    ...  ...   ...     ...     ...
# 1047  1540.68   9.33  2022     11    7     5       8      32
# 1048  1540.83   7.66  2022     11    7     5       8      34
# 1049  1540.85   6.07  2022     11    7     5       8      36
# 1050  1540.83   4.61  2022     11    7     5       8      38
# 1051  1540.84   3.00  2022     11    7     5       8      40
#
#                     date          time_shift  time_diff
# 19   2022-11-07 04:34:16                 NaT        NaN
# 20   2022-11-07 04:34:18 2022-11-07 04:34:16        2.0
# 21   2022-11-07 04:34:20 2022-11-07 04:34:18        2.0
# 22   2022-11-07 04:34:22 2022-11-07 04:34:20        2.0
# 23   2022-11-07 04:34:24 2022-11-07 04:34:22        2.0
# ...                  ...                 ...        ...
# 1047 2022-11-07 05:08:32 2022-11-07 05:08:30        2.0
# 1048 2022-11-07 05:08:34 2022-11-07 05:08:32        2.0
# 1049 2022-11-07 05:08:36 2022-11-07 05:08:34        2.0
# 1050 2022-11-07 05:08:38 2022-11-07 05:08:36        2.0
# 1051 2022-11-07 05:08:40 2022-11-07 05:08:38        2.0
#
# [1033 rows x 11 columns]

# %%
df['depth_shifted']=df['Depth'].shift()

# %%
df['depth_step(m)']=abs(df['Depth']-df['depth_shifted'])

# %%
df['dip_speed(m/s)'] = abs(df['depth_step']/df['time_diff'])

# %%
df
# Out:
#           SoS  Depth  year  month  day  hour  minute  second  \
# 19    1540.96   2.93  2022     11    7     4      34      16
# 20    1540.92   3.44  2022     11    7     4      34      18
# 21    1540.92   3.95  2022     11    7     4      34      20
# 22    1540.90   4.48  2022     11    7     4      34      22
# 23    1540.91   5.29  2022     11    7     4      34      24
# ...       ...    ...   ...    ...  ...   ...     ...     ...
# 1047  1540.68   9.33  2022     11    7     5       8      32
# 1048  1540.83   7.66  2022     11    7     5       8      34
# 1049  1540.85   6.07  2022     11    7     5       8      36
# 1050  1540.83   4.61  2022     11    7     5       8      38
# 1051  1540.84   3.00  2022     11    7     5       8      40
#
#                     date          time_shift  time_diff  depth_shifted  \
# 19   2022-11-07 04:34:16                 NaT        NaN            NaN
# 20   2022-11-07 04:34:18 2022-11-07 04:34:16        2.0           2.93
# 21   2022-11-07 04:34:20 2022-11-07 04:34:18        2.0           3.44
# 22   2022-11-07 04:34:22 2022-11-07 04:34:20        2.0           3.95
# 23   2022-11-07 04:34:24 2022-11-07 04:34:22        2.0           4.48
# ...                  ...                 ...        ...            ...
# 1047 2022-11-07 05:08:32 2022-11-07 05:08:30        2.0          10.40
# 1048 2022-11-07 05:08:34 2022-11-07 05:08:32        2.0           9.33
# 1049 2022-11-07 05:08:36 2022-11-07 05:08:34        2.0           7.66
# 1050 2022-11-07 05:08:38 2022-11-07 05:08:36        2.0           6.07
# 1051 2022-11-07 05:08:40 2022-11-07 05:08:38        2.0           4.61
#
#       depth_step  depth_step(m)  dip_speed  dip_speed(m/s)
# 19           NaN            NaN        NaN             NaN
# 20          0.51           0.51      0.255           0.255
# 21          0.51           0.51      0.255           0.255
# 22          0.53           0.53      0.265           0.265
# 23          0.81           0.81      0.405           0.405
# ...          ...            ...        ...             ...
# 1047       -1.07           1.07     -0.535           0.535
# 1048       -1.67           1.67     -0.835           0.835
# 1049       -1.59           1.59     -0.795           0.795
# 1050       -1.46           1.46     -0.730           0.730
# 1051       -1.61           1.61     -0.805           0.805
#
# [1033 rows x 16 columns]

# %% [markdown]
# ### defining dip direction (up or down)

# %%
tmax=df['Time'][df['Depth']==df['Depth'].max()].index                                               # find index of the max depth value
df['direction'] = np.where(df['level_0']<=tmax[0], 'down', 'up')                                    # create 'direction' columns based on index level
df.drop(['level_0','index'],axis=1,inplace=True)                                                    # remove unused column

# %% [markdown]
# ### spliting dataframe

# %%
df_up=df[df['direction']=='up']
df_down=df[df['direction']=='down']

top = df[df['Depth']<=50] # top 50m dataframe
top_up=top[top['direction']=='up']
top_down=top[top['direction']=='down']

# %%
 
fig = make_subplots(
    rows=1,cols=2,
    subplot_titles=("Full column","Top 50m")
                   )

fig.add_trace(
    go.Scatter(x=df_down['SoS'],y=df_down['Depth'],line=dict(color='royalblue'),showlegend=False),
    row=1,col=1
)

fig.add_trace(
    go.Scatter(x=df_up['SoS'],y=df_up['Depth'],line=dict(color='brown'),showlegend=False),
    row=1,col=1
)


fig.add_trace(
    go.Scatter(x=top_down["SoS"],y=top_down["Depth"],line=dict(color='royalblue'),name='down'),
    row=1,col=2
)

fig.add_trace(
    go.Scatter(x=top_up["SoS"],y=top_up["Depth"],line=dict(color='brown'),name='up'),
    row=1,col=2
)


fig.update_yaxes(autorange="reversed", row=1, col=1)
fig.update_yaxes(autorange="reversed", row=1, col=2)
.91,1499.93,1499.95,1499.92,1499.92,1499.89,1499.86,1499.85,1499.82,1499.78,1499.77,1499.71,1499.64,1499.62,1499.61,1499.64,1499.66,1499.68,1499.69,1499.72,1499.74,1499.76,1499.68,1499.66,1499.66,1499.65,1499.7,1499.72,1499.73,1499.76,1499.77,1499.78,1499.78,1499.8,1499.79,1499.78,1499.74,1499.77,1499.74,1499.72,1499.65,1499.62,1499.62,1499.66,1499.66,1499.72,1499.75,1499.79,1499.81,1499.84,1499.78,1499.6,1499.32,1499.18,1499.12,1499.11,1499.05,1498.94,1498.86,1498.74,1498.54,1498.42,1498.36,1498.17,1498.01,1497.87,1497.86,1497.82,1497.83,1497.83,1497.75,1497.69,1497.63,1497.62,1497.55,1497.44,1497.28,1497.18,1497.18,1497.22,1497.22,1497.15,1497.05,1496.91,1496.8,1496.75,1496.77,1496.71,1496.67,1496.6,1496.57,1496.54,1496.47,1496.35,1496.28,1496.22,1496.14,1496.08,1496.02,1495.92,1495.85,1495.78,1495.74,1495.71,1495.67,1495.61,1495.6,1495.6,1495.64,1495.67,1495.56,1495.49,1495.46,1495.42,1495.44,1495.42,1495.39,1495.31,1495.28,1495.3,1495.29,1495.28,1495.26,1495.24,1495.23,1495.19,1495.19,1495.13,1494.95,1494.92,1494.89,1494.91,1494.9,1494.93,1494.95,1494.93,1494.98,1494.99,1495.01,1495.04,1495.06,1495.08,1495.09,1495.11,1495.11,1495.14,1495.14,1495.11,1495.05,1495.07,1495.08,1495.09,1495.03,1495.01,1494.97,1494.95,1494.94,1494.9,1494.88,1494.9,1494.88,1494.88,1494.87,1494.92,1494.91,1494.92,1494.94,1494.99,1494.98,1494.98,1494.98,1494.94,1494.87,1494.83,1494.78,1494.71,1494.66,1494.64,1494.58,1494.54,1494.55,1494.6,1494.61,1494.65,1494.68,1494.66,1494.61,1494.51,1494.45,149 ...

# %%
df_down
# Out:
#          SoS   Depth        Date      Time direction
# 0    1540.96    2.93  2022-11-07  04:34:16      down
# 1    1540.92    3.44  2022-11-07  04:34:18      down
# 2    1540.92    3.95  2022-11-07  04:34:20      down
# 3    1540.90    4.48  2022-11-07  04:34:22      down
# 4    1540.91    5.29  2022-11-07  04:34:24      down
# ..       ...     ...         ...       ...       ...
# 527  1493.17  983.11  2022-11-07  04:51:50      down
# 528  1493.17  984.12  2022-11-07  04:51:52      down
# 529  1493.18  984.53  2022-11-07  04:51:54      down
# 530  1493.17  984.94  2022-11-07  04:51:56      down
# 531  1493.16  985.08  2022-11-07  04:51:58      down
#
# [532 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1033 entries, 0 to 1032
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   level_0  1033 non-null   int64
#  1   index    1033 non-null   int64
#  2   SoS      1033 non-null   float64
#  3   Depth    1033 non-null   float64
#  4   Date     1033 non-null   object
#  5   Time     1033 non-null   object
# dtypes: float64(2), int64(2), object(2)
# memory usage: 48.5+ KB

# %%
type(df['Time'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# ### reading files in directory and creating a list with their names

# %%
import os

# %%
path = "/home/rod/Documents/DataScience/my_projects/nav/tsdip/data"
dir_list = os.listdir(path)

# %%
new = []
for i in dir_list:
    new.append(i.split(sep='.')[0])

# %%
new
# Out:
# ['tsdip-01', 'tsdip-02']
